# %%
from CAN_processor import load_dbc, load_mf4, decode_obd2,filter_obd2, plot_signals

DBC_PATH = r"C:\Users\dell\Desktop\MBGP Mentoring\Programming\Excel Data\obd2-pack-v5\obd2-dbc\CSS-Electronics-11-bit-OBD2-v2.2.dbc"
MF4_PATH = r"C:\Users\dell\Desktop\MBGP Mentoring\Programming\Excel Data\obd2-pack-v5\obd2-sample-data\Renault Kadjar 2020\00000001.MF4"

db = load_dbc(DBC_PATH)
raw_df = load_mf4(MF4_PATH)

obd2_df = filter_obd2(raw_df)

decoded_df = decode_obd2(obd2_df, db)

signals_to_plot = [
    'S01PID05_EngineCoolantTemp',
    'S01PID0C_EngineRPM',
    'S01PID0D_VehicleSpeed',
    'S01PID10_MAFAirFlowRate',
    'S01PID11_ThrottlePosition'
]

plotting = plot_signals(decoded_df, signals_to_plot, title='Renault Kadjar OBD2 Data')
# Out:
# DBC loaded : C:\Users\dell\Desktop\MBGP Mentoring\Programming\Excel Data\obd2-pack-v5\obd2-dbc\CSS-Electronics-11-bit-OBD2-v2.2.dbc
# Messages : 1
# MF4 loaded : C:\Users\dell\Desktop\MBGP Mentoring\Programming\Excel Data\obd2-pack-v5\obd2-sample-data\Renault Kadjar 2020\00000001.MF4
# Total frames  : 3077765
# Time range    : 0.0s → 2068.4593s
# OBD2 Frames : 5458  (ID= 2024)
# Decoded Signals : 5458
# Signals found : ['Length', 'Response', 'Service', 'S01PID', 'S01PID0C_EngineRPM', 'S01PID0D_VehicleSpeed', 'S01PID10_MAFAirFlowRate', 'S01PID11_ThrottlePosition', 'S01PID5E_EngineFuelRate', 'S01PID5C_EngineOilTemp', 'S01PID62_ActualEngTorqPct', 'S01PID42_ControlModuleVolt', 'S01PID33_AbsBaroPres', 'S01PID04_CalcEngineLoad', 'S01PID0F_IntakeAirTemperature', 'S01PID2F_FuelTankLevel', 'S01PID05_EngineCoolantTemp', 'S01PID0B_IntakeManiAbsPress']

# %%
decoded_df
# Out:
#             Length  Response  Service  S01PID  S01PID05_EngineCoolantTemp  \
# timestamps
# 0.02960          3         4        1       5                        18.0
# 0.09115          4         4        1      12                         NaN
# 0.11150          3         4        1      13                         NaN
# 0.13200          4         4        1      16                         NaN
# 0.15295          3         4        1      17                         NaN
# ...            ...       ...      ...     ...                         ...
# 1327.84645       3         4        1      17                         NaN
# 1327.98605       4         4        1      12                         NaN
# 1328.00630       3         4        1      13                         NaN
# 1328.02675       4         4        1      16                         NaN
# 1328.04315       3         4        1      17                         NaN
#
#             S01PID0C_EngineRPM  S01PID0D_VehicleSpeed  \
# timestamps
# 0.02960                    NaN                    NaN
# 0.09115                 1178.0                    NaN
# 0.11150                    NaN                    0.0
# 0.13200                    NaN                    NaN
# 0.15295                    NaN                    NaN
# ...                        ...                    ...
# 1327.84645                 NaN                    NaN
# 1327.98605                 0.0                    NaN
# 1328.00630                 NaN                    0.0
# 1328.02675                 NaN                    NaN
# 1328.04315                 NaN                    NaN
#
#             S01PID10_MAFAirFlowRate  S01PID11_ThrottlePosition  \
# timestamps
# 0.02960                         NaN                        NaN
# 0.09115                         NaN                        NaN
# 0.11150                         NaN                        NaN
# 0.13200                        4.67                        NaN
# 0.15295                         NaN                   18.43152
# ...                             ...                        ...
# 1327.84645                      NaN                   18.43152
# 1327.98605                      NaN                        NaN
# 1328.00630                      NaN                        NaN
# 1328.02675                     0.21                        NaN
# 1328.04315                      NaN                   18.43152
#
#             S01PID00_PIDsSupported_01_20  S01PID40_PIDsSupported_41_60
# timestamps
# 0.02960                              NaN                           NaN
# 0.09115                              NaN                           NaN
# 0.11150                              NaN                           NaN
# 0.13200                              NaN                           NaN
# 0.15295                              NaN                           NaN
# ...                                  ...                           ...
# 1327.84645                           NaN                           NaN
# 1327.98605                           NaN                           NaN
# 1328.00630                           NaN                           NaN
# 1328.02675                           NaN                           NaN
# 1328.04315                           NaN                           NaN
#
# [27521 rows x 11 columns]

# %%
raw_df
# Out:
#             BusChannel    ID  CAN_DataFrame.CAN_DataFrame.IDE  \
# timestamps
# 0.00000            1.0  1102                              0.0
# 0.00160            1.0   786                              0.0
# 0.00175            1.0   224                              0.0
# 0.00200            1.0   225                              0.0
# 0.00225            1.0   665                              0.0
# ...                ...   ...                              ...
# 2068.45805         1.0   413                              0.0
# 2068.45860         1.0   346                              0.0
# 2068.45885         1.0   348                              0.0
# 2068.45910         1.0   349                              0.0
# 2068.45930         1.0   350                              0.0
#
#             CAN_DataFrame.CAN_DataFrame.DLC  DataLength  \
# timestamps
# 0.00000                                   8         8.0
# 0.00160                                   8         8.0
# 0.00175                                   5         5.0
# 0.00200                                   8         8.0
# 0.00225                                   8         8.0
# ...                                     ...         ...
# 2068.45805                                6         6.0
# 2068.45860                                6         6.0
# 2068.45885                                8         8.0
# 2068.45910                                8         8.0
# 2068.45930                                8         8.0
#
#                                            DataBytes  Dir
# timestamps
# 0.00000          [135, 47, 250, 225, 18, 64, 47, 63]  0.0
# 0.00160              [85, 0, 12, 71, 254, 32, 0, 57]  0.0
# 0.00175           [203, 127, 252, 127, 239, 0, 0, 0]  0.0
# 0.00200     [255, 255, 255, 255, 255, 255, 100, 161]  0.0
# 0.00225        [255, 255, 255, 24, 16, 24, 255, 240]  0.0
# ...                                              ...  ...
# 2068.45805         [56, 127, 255, 255, 255, 8, 0, 0]  0.0
# 2068.45860            [72, 160, 39, 216, 0, 0, 0, 0]  0.0
# 2068.45885         [42, 48, 56, 179, 131, 42, 99, 0]  0.0
# 2068.45910       [40, 46, 130, 240, 24, 72, 68, 254]  0.0
# 2068.45930     [56, 51, 136, 52, 146, 247, 113, 153]  0.0
#
# [3077765 rows x 7 columns]

# %%
obd2_dataf
# Out:
#             BusChannel    ID  CAN_DataFrame.CAN_DataFrame.IDE  \
# timestamps
# 0.02960              1  2024                                0
# 0.09115              1  2024                                0
# 0.11150              1  2024                                0
# 0.13200              1  2024                                0
# 0.15295              1  2024                                0
# ...                ...   ...                              ...
# 1327.84645           1  2024                                0
# 1327.98605           1  2024                                0
# 1328.00630           1  2024                                0
# 1328.02675           1  2024                                0
# 1328.04315           1  2024                                0
#
#             CAN_DataFrame.CAN_DataFrame.DLC  DataLength  \
# timestamps
# 0.02960                                   8           8
# 0.09115                                   8           8
# 0.11150                                   8           8
# 0.13200                                   8           8
# 0.15295                                   8           8
# ...                                     ...         ...
# 1327.84645                                8           8
# 1327.98605                                8           8
# 1328.00630                                8           8
# 1328.02675                                8           8
# 1328.04315                                8           8
#
#                                 DataBytes  Dir  \
# timestamps
# 0.02960        [3, 65, 5, 58, 0, 0, 0, 0]    0
# 0.09115     [4, 65, 12, 18, 104, 0, 0, 0]    0
# 0.11150        [3, 65, 13, 0, 0, 0, 0, 0]    0
# 0.13200      [4, 65, 16, 1, 211, 0, 0, 0]    0
# 0.15295       [3, 65, 17, 47, 0, 0, 0, 0]    0
# ...                                   ...  ...
# 1327.84645    [3, 65, 17, 47, 0, 0, 0, 0]    0
# 1327.98605     [4, 65, 12, 0, 0, 0, 0, 0]    0
# 1328.00630     [3, 65, 13, 0, 0, 0, 0, 0]    0
# 1328.02675    [4, 65, 16, 0, 21, 0, 0, 0]    0
# 1328.04315    [3, 65, 17, 47, 0, 0, 0, 0]    0
#
#             CAN_DataFrame.CAN_DataFrame.EDL  CAN_DataFrame.CAN_DataFrame.BRS
# timestamps
# 0.02960                                   0                                0
# 0.09115                                   0                                0
# 0.11150                                   0                                0
# 0.13200                                   0                                0
# 0.15295                                   0                                0
# ...                                     ...                              ...
# 1327.84645                                0                                0
# 1327.98605                                0                                0
# 1328.00630                                0                                0
# 1328.02675                                0                                0
# 1328.04315                                0                                0
#
# [27521 rows x 9 columns]
